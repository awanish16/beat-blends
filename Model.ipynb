# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # **Data Loading**

# %%
df = pd.read_csv('Data/features_30_sec.csv')
df
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
df.columns
# Out:
# Index(['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
#        'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
df=df.drop(columns=['length','label'])

# %%
df.columns
# Out:
# Index(['filename', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
#        'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
data=df.copy()

# %%
data.set_index('filename', drop=True, inplace=True)

# %%
data.columns
# Out:
# Index(['chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var',
#        'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
data.shape
# Out:
# (1000, 57)

# %%
data.head()
# Out:
#                  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# filename
# blues.00000.wav          0.350088         0.088757  0.130228  0.002827
# blues.00001.wav          0.340914         0.094980  0.095948  0.002373
# blues.00002.wav          0.363637         0.085275  0.175570  0.002746
# blues.00003.wav          0.404785         0.093999  0.141093  0.006346
# blues.00004.wav          0.308526         0.087841  0.091529  0.002303
#
#                  spectral_centroid_mean  spectral_centroid_var  \
# filename
# blues.00000.wav             1784.165850          129774.064525
# blues.00001.wav             1530.176679          375850.073649
# blues.00002.wav             1552.811865          156467.643368
# blues.00003.wav             1070.106615          184355.942417
# blues.00004.wav             1835.004266          343399.939274
#
#                  spectral_bandwidth_mean  spectral_bandwidth_var  \
# filename
# ...

# %%
data.tail()
# Out:
#                 chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# filename
# rock.00095.wav          0.352063         0.080487  0.079486  0.000345
# rock.00096.wav          0.398687         0.075086  0.076458  0.000588
# rock.00097.wav          0.432142         0.075268  0.081651  0.000322
# rock.00098.wav          0.362485         0.091506  0.083860  0.001211
# rock.00099.wav          0.358401         0.085884  0.054454  0.000336
#
#                 spectral_centroid_mean  spectral_centroid_var  \
# filename
# rock.00095.wav             2008.149458          282174.689224
# rock.00096.wav             2006.843354          182114.709510
# rock.00097.wav             2077.526598          231657.968040
# rock.00098.wav             1398.699344          240318.731073
# rock.00099.wav             1609.795082          422203.216152
#
#                 spectral_bandwidth_mean  spectral_bandwidth_var  rolloff_mean  \
# filename
# ...

# %%
data.describe()
# Out:
#        chroma_stft_mean  chroma_stft_var     rms_mean      rms_var  \
# count       1000.000000      1000.000000  1000.000000  1000.000000
# mean           0.378682         0.086340     0.130930     0.003051
# std            0.081705         0.007735     0.065683     0.003634
# min            0.171939         0.044555     0.005276     0.000004
# 25%            0.319562         0.082298     0.086657     0.000942
# 50%            0.383148         0.086615     0.122443     0.001816
# 75%            0.435942         0.091256     0.175682     0.003577
# max            0.663685         0.108111     0.397973     0.027679
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             1000.000000           1.000000e+03              1000.000000
# mean              2201.780898           4.696916e+05              2242.541070
# std                715.960600           4.008995e+05               526.316473
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, blues.00000.wav to rock.00099.wav
# Data columns (total 57 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   chroma_stft_mean         1000 non-null   float64
#  1   chroma_stft_var          1000 non-null   float64
#  2   rms_mean                 1000 non-null   float64
#  3   rms_var                  1000 non-null   float64
#  4   spectral_centroid_mean   1000 non-null   float64
#  5   spectral_centroid_var    1000 non-null   float64
#  6   spectral_bandwidth_mean  1000 non-null   float64
#  7   spectral_bandwidth_var   1000 non-null   float64
#  8   rolloff_mean             1000 non-null   float64
#  9   rolloff_var              1000 non-null   float64
#  10  zero_crossing_rate_mean  1000 non-null   float64
#  11  zero_crossing_rate_var   1000 non-null   float64
#  12  harmony_mean             1000 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# chroma_stft_mean           0
# chroma_stft_var            0
# rms_mean                   0
# rms_var                    0
# spectral_centroid_mean     0
# spectral_centroid_var      0
# spectral_bandwidth_mean    0
# spectral_bandwidth_var     0
# rolloff_mean               0
# rolloff_var                0
# zero_crossing_rate_mean    0
# zero_crossing_rate_var     0
# harmony_mean               0
# harmony_var                0
# perceptr_mean              0
# perceptr_var               0
# tempo                      0
# mfcc1_mean                 0
# mfcc1_var                  0
# mfcc2_mean                 0
# mfcc2_var                  0
# mfcc3_mean                 0
# mfcc3_var                  0
# mfcc4_mean                 0
# mfcc4_var                  0
# mfcc5_mean                 0
# mfcc5_var                  0
# mfcc6_mean                 0
# mfcc6_var                  0
# mfcc7_mean                 0
# mfcc7_var                  0
# mfcc8_mean                 0
# ...

# %% [markdown]
# # **Data Analysis**

# %%
data.corr()
# Out:
#                          chroma_stft_mean  chroma_stft_var  rms_mean  \
# chroma_stft_mean                 1.000000        -0.461729  0.499926
# chroma_stft_var                 -0.461729         1.000000 -0.078777
# rms_mean                         0.499926        -0.078777  1.000000
# rms_var                          0.261544         0.290138  0.607399
# spectral_centroid_mean           0.615728        -0.246441  0.510154
# spectral_centroid_var            0.285926         0.305819  0.324077
# spectral_bandwidth_mean          0.517710        -0.036896  0.530017
# spectral_bandwidth_var           0.041088         0.346907  0.099830
# rolloff_mean                     0.598122        -0.168721  0.537902
# rolloff_var                      0.117139         0.383134  0.200083
# zero_crossing_rate_mean          0.554771        -0.470186  0.332163
# zero_crossing_rate_var           0.355920         0.169289  0.319304
# harmony_mean                     0.031963        -0.006378  0.064440
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, palette='Set3')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import math

num_cols = 4
num_rows = math.ceil(len(df.columns[1:-1]) / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, num_rows*4))

for ax, col in zip(axes.flatten(), df.columns[1:-1]):
    df[col].hist(ax=ax, bins=20, color='skyblue', edgecolor='black', linewidth=1.5)
    ax.set_title(col)
    ax.set_xlabel('')
    ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(data), columns=data.columns, index=data.index)
df_normalized.head()
# Out:
#                  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# filename
# blues.00000.wav          0.362279         0.695468  0.318188  0.101983
# blues.00001.wav          0.343622         0.793392  0.230894  0.085580
# blues.00002.wav          0.389832         0.640692  0.433652  0.099064
# blues.00003.wav          0.473508         0.777954  0.345856  0.229160
# blues.00004.wav          0.277759         0.681062  0.219641  0.083075
#
#                  spectral_centroid_mean  spectral_centroid_var  \
# filename
# blues.00000.wav                0.314117               0.040233
# blues.00001.wav                0.248405               0.121475
# blues.00002.wav                0.254261               0.049046
# blues.00003.wav                0.129376               0.058253
# blues.00004.wav                0.327270               0.110761
#
#                  spectral_bandwidth_mean  spectral_bandwidth_var  \
# filename
# ...

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df_normalized, palette='Set3')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Model**

# %%
model = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(df_normalized)

# %%
distances, indices = model.kneighbors([list(dict(X.iloc[5]).values())])
print(df_normalized.iloc[indices[0][1]].name)
# Out:
# country.00076.wav
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
